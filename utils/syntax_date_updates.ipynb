# %%
import pandas as pd
import calendar
import plotly.express as px

# %%
df = pd.read_csv('/Users/jackturek/Documents/Repos/SATX-Campaign-Finance/data/campaign_finance20241031.csv')
df.head(), df.columns
# Out:
# (    Report Id:                    Name: Contact Type:  \
#  0  View Report           Rudolph, Irina   Contributor
#  1  View Report             Chapa, Jacob   Contributor
#  2  View Report             Chapa, Jacob   Contributor
#  3  View Report          Garcia, Cesario   Contributor
#  4  View Report  Kessler For San Antonio   Expenditure
#
#                    Report Type:  Amount:                            strVal  \
#  0                           UC   400.00          Unexpended Contributions
#  1                           UC   200.00          Unexpended Contributions
#  2                           UC    91.32          Unexpended Contributions
#  3                           UC   200.00          Unexpended Contributions
#  4  January 15 Semi-Annual 2019     0.00  Notice From Political Committees
#
#     Cand/Committee: Election Date:  Id  ReportId        FilerName  \
#  0  Patricia Varela            NaN  50      3048  Patricia Varela
#  1  Patricia Varela            NaN  51      3048  Patricia Varela
#  2  Patricia Varela            NaN  52      3048  Patricia Varela
#  3  Patricia Varela            NaN  53      3048  Patricia Varela
#  4     brad kessler         5/4/19  60      2185     brad kessler
#
#    Report Type Code:  Count:     TransDate:    CreatedDt:  ZipCode  \
#  0                 U       1   5/1/23 00:00  5/5/23 15:00    78251
#  1                 U       2  3/31/23 00:00  5/5/23 15:00    78254
#  2                 U       3   5/1/23 00:00  5/5/23 15:00    78254
#  3                 U       4   4/3/23 00:00  5/5/23 15:00    78249
#  4                 C       5  1/15/19 13:33  1/7/19 05:17    78212
#
#                                            ReportLink
#  0  https://webapp5.sanantonio.gov/CampFinHistoric...
#  1  https://webapp5.sanantonio.gov/CampFinHistoric...
#  2  https://webapp5.sanantonio.gov/CampFinHistoric...
#  3  https://webapp5.sanantonio.gov/CampFinHistoric...
#  4  https://webapp5.sanantonio.gov/CampFinHistoric...  ,
#  Index(['Report Id:', 'Name:', 'Contact Type:', 'Report Type:', 'Amount:',
#         'strVal', 'Cand/Committee:', 'Election Date:', 'Id', 'ReportId',
#         'FilerName', 'Report Type Code:', 'Count:', 'TransDate:', 'CreatedDt:',
#         'ZipCode', 'ReportLink'],
#        dtype='object'))

# %%
df['Election Date:'] = pd.to_datetime(df['Election Date:'], format='%m/%d/%y',
                                      errors='coerce')
df['TransDate:'] = pd.to_datetime(df['TransDate:'],
                                 errors='coerce')
df['CreatedDt:'] = pd.to_datetime(df['CreatedDt:'], 
                                  errors='coerce')
df.head()
# Out:
# /var/folders/h6/yxy6glj14rd2c83llgj50xnc0000gn/T/ipykernel_69174/2566515638.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['TransDate:'] = pd.to_datetime(df['TransDate:'],
# /var/folders/h6/yxy6glj14rd2c83llgj50xnc0000gn/T/ipykernel_69174/2566515638.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['CreatedDt:'] = pd.to_datetime(df['CreatedDt:'],
#     Report Id:                    Name: Contact Type:  \
# 0  View Report           Rudolph, Irina   Contributor
# 1  View Report             Chapa, Jacob   Contributor
# 2  View Report             Chapa, Jacob   Contributor
# 3  View Report          Garcia, Cesario   Contributor
# 4  View Report  Kessler For San Antonio   Expenditure
#
#                   Report Type:  Amount:                            strVal  \
# 0                           UC   400.00          Unexpended Contributions
# 1                           UC   200.00          Unexpended Contributions
# 2                           UC    91.32          Unexpended Contributions
# 3                           UC   200.00          Unexpended Contributions
# 4  January 15 Semi-Annual 2019     0.00  Notice From Political Committees
#
#    Cand/Committee: Election Date:  Id  ReportId        FilerName  \
# 0  Patricia Varela            NaT  50      3048  Patricia Varela
# 1  Patricia Varela            NaT  51      3048  Patricia Varela
# 2  Patricia Varela            NaT  52      3048  Patricia Varela
# 3  Patricia Varela            NaT  53      3048  Patricia Varela
# 4     brad kessler     2019-05-04  60      2185     brad kessler
#
#   Report Type Code:  Count:          TransDate:          CreatedDt:  ZipCode  \
# 0                 U       1 2023-05-01 00:00:00 2023-05-05 15:00:00    78251
# 1                 U       2 2023-03-31 00:00:00 2023-05-05 15:00:00    78254
# 2                 U       3 2023-05-01 00:00:00 2023-05-05 15:00:00    78254
# 3                 U       4 2023-04-03 00:00:00 2023-05-05 15:00:00    78249
# 4                 C       5 2019-01-15 13:33:00 2019-01-07 05:17:00    78212
#
#                                           ReportLink
# 0  https://webapp5.sanantonio.gov/CampFinHistoric...
# 1  https://webapp5.sanantonio.gov/CampFinHistoric...
# 2  https://webapp5.sanantonio.gov/CampFinHistoric...
# 3  https://webapp5.sanantonio.gov/CampFinHistoric...
# 4  https://webapp5.sanantonio.gov/CampFinHistoric...

# %%
df['TransDate:'] = df['TransDate:'].dt.normalize()
df['CreatedDt:'] = df['CreatedDt:'].dt.normalize()
df.head()
# Out:
#     Report Id:                    Name: Contact Type:  \
# 0  View Report           Rudolph, Irina   Contributor
# 1  View Report             Chapa, Jacob   Contributor
# 2  View Report             Chapa, Jacob   Contributor
# 3  View Report          Garcia, Cesario   Contributor
# 4  View Report  Kessler For San Antonio   Expenditure
#
#                   Report Type:  Amount:                            strVal  \
# 0                           UC   400.00          Unexpended Contributions
# 1                           UC   200.00          Unexpended Contributions
# 2                           UC    91.32          Unexpended Contributions
# 3                           UC   200.00          Unexpended Contributions
# 4  January 15 Semi-Annual 2019     0.00  Notice From Political Committees
#
#    Cand/Committee: Election Date:  Id  ReportId        FilerName  \
# 0  Patricia Varela            NaT  50      3048  Patricia Varela
# 1  Patricia Varela            NaT  51      3048  Patricia Varela
# 2  Patricia Varela            NaT  52      3048  Patricia Varela
# 3  Patricia Varela            NaT  53      3048  Patricia Varela
# 4     brad kessler     2019-05-04  60      2185     brad kessler
#
#   Report Type Code:  Count: TransDate: CreatedDt:  ZipCode  \
# 0                 U       1 2023-05-01 2023-05-05    78251
# 1                 U       2 2023-03-31 2023-05-05    78254
# 2                 U       3 2023-05-01 2023-05-05    78254
# 3                 U       4 2023-04-03 2023-05-05    78249
# 4                 C       5 2019-01-15 2019-01-07    78212
#
#                                           ReportLink
# 0  https://webapp5.sanantonio.gov/CampFinHistoric...
# 1  https://webapp5.sanantonio.gov/CampFinHistoric...
# 2  https://webapp5.sanantonio.gov/CampFinHistoric...
# 3  https://webapp5.sanantonio.gov/CampFinHistoric...
# 4  https://webapp5.sanantonio.gov/CampFinHistoric...

# %%
# Create new cols for Election, Trans, Created calendar
df['Election Year'] = df['Election Date:'].dt.year
df['Election Month'] = df['Election Date:'].dt.month
df['Election Day'] = df['Election Date:'].dt.day

# Break down CreatedDt into Year, Month, Day
df['Created Year'] = df['CreatedDt:'].dt.year
df['Created Month'] = df['CreatedDt:'].dt.month
df['Created Day'] = df['CreatedDt:'].dt.day

# Break down TransDate into Year, Month, Day
df['Trans Year'] = df['TransDate:'].dt.year
df['Trans Month'] = df['TransDate:'].dt.month
df['Trans Day'] = df['TransDate:'].dt.day

# %%
# Map month numbers to month names
df['Election Month'] = df['Election Month'].apply(lambda x: calendar.month_name[int(x)] if pd.notnull(x) else None)
df['Created Month'] = df['Created Month'].apply(lambda x: calendar.month_name[int(x)] if pd.notnull(x) else None)
df['Trans Month'] = df['Trans Month'].apply(lambda x: calendar.month_name[int(x)] if pd.notnull(x) else None)

# Convert year and day cols to integers
df['Election Year'] = df['Election Year'].astype('Int64')
df['Election Day'] = df['Election Day'].astype('Int64')
df['Created Year'] = df['Created Year'].astype('Int64')
df['Created Day'] = df['Created Day'].astype('Int64')
df['Trans Year'] = df['Trans Year'].astype('Int64')
df['Trans Day'] = df['Trans Day'].astype('Int64')

df.head()
# Out:
#     Report Id:                    Name: Contact Type:  \
# 0  View Report           Rudolph, Irina   Contributor
# 1  View Report             Chapa, Jacob   Contributor
# 2  View Report             Chapa, Jacob   Contributor
# 3  View Report          Garcia, Cesario   Contributor
# 4  View Report  Kessler For San Antonio   Expenditure
#
#                   Report Type:  Amount:                            strVal  \
# 0                           UC   400.00          Unexpended Contributions
# 1                           UC   200.00          Unexpended Contributions
# 2                           UC    91.32          Unexpended Contributions
# 3                           UC   200.00          Unexpended Contributions
# 4  January 15 Semi-Annual 2019     0.00  Notice From Political Committees
#
#    Cand/Committee: Election Date:  Id  ReportId  ...  \
# 0  Patricia Varela            NaT  50      3048  ...
# 1  Patricia Varela            NaT  51      3048  ...
# 2  Patricia Varela            NaT  52      3048  ...
# 3  Patricia Varela            NaT  53      3048  ...
# 4     brad kessler     2019-05-04  60      2185  ...
#
#                                           ReportLink Election Year  \
# 0  https://webapp5.sanantonio.gov/CampFinHistoric...          <NA>
# 1  https://webapp5.sanantonio.gov/CampFinHistoric...          <NA>
# 2  https://webapp5.sanantonio.gov/CampFinHistoric...          <NA>
# 3  https://webapp5.sanantonio.gov/CampFinHistoric...          <NA>
# 4  https://webapp5.sanantonio.gov/CampFinHistoric...          2019
#
#    Election Month Election Day Created Year  Created Month Created Day  \
# 0            None         <NA>         2023            May           5
# 1            None         <NA>         2023            May           5
# 2            None         <NA>         2023            May           5
# 3            None         <NA>         2023            May           5
# 4             May            4         2019        January           7
#
#    Trans Year Trans Month  Trans Day
# 0        2023         May          1
# 1        2023       March         31
# 2        2023         May          1
# 3        2023       April          3
# 4        2019     January         15
#
# [5 rows x 26 columns]

# %%
# Fix Manny Pelaez name
df['Cand/Committee:'] = df['Cand/Committee:'].replace({
    'Manny Pelaez Pelaez': 'Manny Pelaez',
    'Manuel Pelaez': 'Manny Pelaez'
})

df['FilerName'] = df['FilerName'].replace({
    'Manny Pelaez Pelaez': 'Manny Pelaez',
    'Manuel Pelaez': 'Manny Pelaez'
})

# Fix Clayton Perry name
df['FilerName'] = df['FilerName'].replace({
    'CLAYTON PERRY': 'Clayton Perry'
})

df['Cand/Committee:'] = df['Cand/Committee:'].replace({
    'CLAYTON PERRY': 'Clayton Perry'
})

df['Cand/Committee:'].unique()
df['FilerName'].unique()
# Out:
# array(['Patricia Varela', 'brad kessler', 'MARIA PEREZ', 'Robert Herrera',
#        'Nicholas Balderas', 'Adriana Garcia', 'Rebecca Viagran',
#        'Tomas Uresti', 'Cory Dennington', 'JASON MATA', 'Ana Sandoval',
#        'Test Candidate', 'Bryan Martin', 'Marina Gavito', 'Sukh Kaur',
#        'Marc Whyte', 'Mario Bravo', 'Justin Holley', 'William Flautt',
#        'Bert Cecconi', 'Anthony Gres', 'Mario Adame', 'Anthony Valdivia',
#        'Denise Gutierrez-Homer', 'Andrew Greene', 'Jada Sullivan',
#        'Elizabeth Campos', 'Reinette King', 'Samantha Sanchez',
#        'Patrick Von Dohlen', 'Liz Campos', 'Ray Basaldua', 'Mark Vargas',
#        'Marie Crabb', 'Teri Castillo', 'Phyllis Viagran', 'JSAON MATA',
#        'Rudy Lopez', 'Norris Darden', 'Erika Moe', 'Kristi Villanueva',
#        'Roberto Rodriguez', 'Dori Brown', 'Chris Dawkins',
#        'Katherine Herrera', 'Patrick Jones', 'Jarrett Lipman',
#        'Denise Gutierrez', 'Joel Solis', 'Christopher Schuchardt',
#        'Ernest Salinas', 'Rose Requenez Hill', 'Gregorio De La Paz',
#        'Christopher Longoria', 'Robert Flores', 'Jeremy Roberts',
#        'Erin Gallegos Reid', 'Daniel Rossiter', 'Sandragrace Martinez',
#        'Andrew Luck', 'Armando Dominguez', 'John Courage',
#        'Alberto Altamirano', 'Sakib Shaikh',
#        'San Antonio First Political Action Committee',
#        'SAN ANTONIANS FOR FISCAL DISCIPLINE',
#        'Secure San Antonios Future', 'Clayton Perry', 'Rey Saldaña',
#        'Manny Pelaez', 'Matthew Pina', 'San Antonio First',
#        'Frankie Gonzales-Wolfe', 'Roberto Treviño', 'Alan Inchaurregui',
#        'Jeanet Reyes', 'William Shaw', 'ismael reyes', 'Will McLeod',
#        'Melissa Cabello Havrda', 'Richard versace', 'Tim Atwood',
#        'Walter Perry', 'Juan Castanuela', 'Johnny Arredondo',
#        'Clayton Whitney', 'ANTONIO DIAZ', 'Keith Toney', 'Joel Mendoza',
#        'Kimberly Grant', 'Richard Ramey', 'Colton Unden',
#        'NIcholas Balderas Campaign', 'Joseph Powell', 'Jilma Davila',
#        'Salena Guipzot', 'Ruben Arciniega', 'Oscar Magaña',
#        'Elise Kibler', 'Ascend PAC Texas', 'ANTHONY VALDIVIA',
#        'Linda Montellano', 'Jada Andrews-Sullivan', 'John Velasquez',
#        'Genevieve Trinidad', 'Theyre Eating Our Lunch PAC',
#        'Theyre Eating Our Lunch SPAC', 'Juan Manuel Medina',
#        'Michael Montano', 'Gregory Brockhouse',
#        'SAWS Accountability Act PAC', 'Keep Pre-K 4 SA',
#        'Yes for Mobility PAC', 'Melisssa Cabello Havrda', 'Juan Medina',
#        'Ready To Work SA', 'Ronald Nirenberg', 'Emily Norwood',
#        'FIX SAPD', 'Norberto Landin', 'Jalen McKee-Rodriguez',
#        'Cynthia Dominguez-Lopez', 'Rodolfo Lopez', 'Gabrien Gregory',
#        'Ezra Johnson', 'Carl Booker', 'Our Power PAC', 'Pharaoh Clark',
#        'Jada Andrew-Sullivan', 'NNEKA CLEAVER', 'Robert Walker',
#        'Ricardo Moreno', 'Suzanne McCarty', 'DAVID TRISTAN',
#        'Andrew Vicencio', 'Marcello Martinez', 'Irma Barron',
#        'Raymond Guzman', 'Christopher Baecker', 'Cyndi Dominguez',
#        'Irina Rudolph', 'Greg Brockhouse',
#        'San Antonio Committee for Police Accountability', 'Walter Murray',
#        'Matthew Gauna', 'Angela Cardona', 'Rafael Vela', 'Cesario Garcia',
#        'Ted Gonzalez', 'Oppose Prop B San Antonio',
#        'Norbert Geremy Landin', 'TFN PAC', 'David Tristan', 'David Yanez',
#        'JASON q', 'San Antonio Equity Alliance', 'Antonio Salinas',
#        'Roberto Trevino',
#        'San antonio Coalition for Police Accountability', 'Cynthia Lopez',
#        'Arturo Espinosa', 'Build SA PAC', 'Ron Nirenberg', 'Edward Giles',
#        'Carla Walker', 'Chris Baecker', 'IRNA Rudolph',
#        'Roberto Rios Ortega', 'Mauricio Madrazo', 'LARRY LA ROSE',
#        'Mario Ortega', 'Michael Samaniego', 'cesario garcia',
#        'David Lara', 'SA Justice Charter PAC', 'Jacob Chapa',
#        'Protect SA PAC', 'San Antonio Safe PAC',
#        'San Antonio Justice Charter PAC', 'Richard Otley',
#        'Margaret Sherwood', 'Armando Bravo', 'Madison Gutierrez',
#        'Gary Allen', 'IRINA RUDOLPH',
#        'Patricia Varela City Council Candidate', 'Diana Uriegas',
#        'James Guild', 'Denise McVea', 'Ivalis Gonzalez',
#        'Angela Aramburu', 'Renew San Antonio', 'Vote Against Prop C',
#        'Shirley Gonzales', 'Rey Saldana'], dtype=object)

# %%
df.to_csv('campaign_finance20241031.csv', index=False)
